# %%
from pathlib import Path
path = Path("./pi.txt")
# print(path)
contents = path.read_text()
# print(contents)
# write_path = Path('.\\text_files\written.txt') # backward slash
# write_path = Path('./text_files\written.txt') # mix
write_path = Path('./text_files/written.txt') # forward slash
write_path.write_text(contents)
lines = contents.splitlines()
pi_digits = ""
for line in lines:
    pi_digits += line+" "
print(pi_digits)

# %%
from pathlib import Path
path = Path("./pi.txt")
content = path.read_text() # this is a string that contains all the data in the file
lines = content.splitlines() # this is array of lines in the file
print(lines[-1])

# %%
from pathlib import Path
path = Path("text_files/pi_million_digits.txt")
content = path.read_text() # this is a string that contains all the data in the file
lines = content.splitlines() # this is array of lines in the file
for line in lines:
    print(line)
