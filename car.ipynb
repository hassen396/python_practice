# %%
from car import Car
def car_caller():
    car = Car('BMW', 'ABC')
    print('the car is: ', car.name)
    car.start()

car_caller()
# Out:
# the car is:  BMW
# starting the BMW car

# %%
nums = [1,2,3,5,6,7,2,4,3]
set_of_nums = set(nums)
print(list(set_of_nums))
# Out:
# [1, 2, 3, 4, 5, 6, 7]
